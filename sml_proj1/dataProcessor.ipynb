# %%
import math
import random
import csv
import sys
import gc
from tqdm import tqdm
# other users followed by particular user. key:userID,value: set of users
user_follow = {}
# other users who follow this user. key: userID,value: set of users.
follow_user = {}
# how many people this user follow
user_follow_num = {}
# how many people follow this user
follow_user_num = {}

# %%
# input train set
with open('train.txt', "r") as f:
    for line in f:
        piece = line.strip().split("\t")
        this_user = piece[0]
        who_follow_this_user = set()
        for i in range(1, len(piece)):
            who_follow_this_user.add(piece[i])
            follow_user.setdefault(piece[i], set(this_user)).add(this_user)
            follow_user_num[piece[i]] = follow_user_num.get(piece[i], 0) + 1
        if len(who_follow_this_user)==0:
            print("user {} has an empty list".format(this_user))
        else:
            user_follow[this_user] = who_follow_this_user
            user_follow_num[this_user] = len(who_follow_this_user)
print("train.txt is inputed")
# Out:
# user 2891796 has an empty list
# user 349769 has an empty list
# user 4599839 has an empty list
# user 862544 has an empty list
# user 4613611 has an empty list
# user 2841393 has an empty list
# user 109695 has an empty list
# user 3247090 has an empty list
# user 3973524 has an empty list
# user 1913301 has an empty list
# user 1292187 has an empty list
# user 939681 has an empty list
# user 4177769 has an empty list
# user 3128447 has an empty list
# user 4659074 has an empty list
# user 509343 has an empty list
# user 1325954 has an empty list
# user 1349278 has an empty list
# user 1710589 has an empty list
# user 2852811 has an empty list
# user 166306 has an empty list
# user 3927240 has an empty list
# user 1556453 has an empty list
# user 4056276 has an empty list
# user 1091416 has an empty list
# user 244655 has an empty list
# user 4615180 has an empty list
# user 2203977 has an empty list
# user 2259763 has an empty list
# user 3326584 has an empty list
# user 2171778 has an empty list
# user 3745536 has an empty list
# user 1146958 has an empty list
# user 2925611 has an empty list
# user 3377679 has an empty list
# user 617576 has an empty list
# user 3996967 has an empty list
# user 1142001 has an empty list
# user 1561959 has an empty list
# user 3810334 has an empty list
# user 1145665 has an empty list
# user 1620005 has an empty list
# user 4640312 has an empty list
# user 2062053 has an empty list
# user 3804060 has an empty list
# user 3182269 has an empty list
# user 1768972 has an empty list
# user 2760462 has an empty list
# user 3902338 has an empty list
# user 4684713 has an empty list
# user 2160061 has an empty list
# user 3683187 has an empty list
# user 1781385 has an empty list
# user 3155725 has an empty list
# user 3108490 has an empty list
# user 886468 has an empty list
# user 301439 has an empty list
# user 3119475 has an empty list
# user 2304782 has an empty list
# user 2482727 has an empty list
# user 180088 has an empty list
# user 4143536 has an empty list
# user 3935029 has an empty list
# user 1118187 has an empty list
# user 1460513 has an empty list
# user 4553892 has an empty list
# user 4837708 has an empty list
# user 968955 has an empty list
# user 3645214 has an empty list
# user 4660550 has an empty list
# user 2022703 has an empty list
# user 422198 has an empty list
# user 4193454 has an empty list
# user 2672145 has an empty list
# user 816838 has an empty list
# user 2523012 has an empty list
# user 1525422 has an empty list
# user 3383892 has an empty list
# user 3397965 has an empty list
# user 3781325 has an empty list
# user 2797634 has an empty list
# user 4349861 has an empty list
# user 1372302 has an empty list
# user 2645032 has an empty list
# user 559307 has an empty list
# user 2535302 has an empty list
# user 1692815 has an empty list
# user 4080789 has an empty list
# user 1690853 has an empty list
# user 42647 has an empty list
# user 3406525 has an empty list
# user 207009 has an empty list
# user 2460634 has an empty list
# user 1078672 has an empty list
# user 1928114 has an empty list
# user 458247 has an empty list
# user 2115131 has an empty list
# user 3837950 has an empty list
# user 2057335 has an empty list
# user 1924366 has an empty list
# user 3505812 has an empty list
# user 2435250 has an empty list
# user 3375926 has an empty list
# user 3548967 has an empty list
# user 692988 has an empty list
# user 4666000 has an empty list
# user 4040071 has an empty list
# user 4289639 has an empty list
# user 4607406 has an empty list
# user 4836626 has an empty list
# user 4483378 has an empty list
# user 1517677 has an empty list
# user 1470222 has an empty list
# user 2810245 has an empty list
# user 1640087 has an empty list
# user 2686717 has an empty list
# user 3431523 has an empty list
# user 2728232 has an empty list
# user 765161 has an empty list
# user 836595 has an empty list
# user 4049504 has an empty list
# user 2598296 has an empty list
# user 993505 has an empty list
# user 1252658 has an empty list
# user 4709114 has an empty list
# user 2638014 has an empty list
# user 3099652 has an empty list
# user 4133204 has an empty list
# user 3743360 has an empty list
# user 2847642 has an empty list
# user 1081726 has an empty list
# user 3136798 has an empty list
# user 2648027 has an empty list
# user 372236 has an empty list
# user 802900 has an empty list
# user 775583 has an empty list
# user 4696002 has an empty list
# user 3687189 has an empty list
# user 2441700 has an empty list
# user 3529663 has an empty list
# user 4190991 has an empty list
# user 2717195 has an empty list
# user 4695590 has an empty list
# user 4290397 has an empty list
# user 633431 has an empty list
# user 2181098 has an empty list
# user 1155422 has an empty list
# user 2786971 has an empty list
# user 2944421 has an empty list
# user 1665699 has an empty list
# user 551503 has an empty list
# user 3914300 has an empty list
# user 692924 has an empty list
# user 99282 has an empty list
# user 2683762 has an empty list
# user 3550172 has an empty list
# user 2834964 has an empty list
# user 4785196 has an empty list
# user 4590913 has an empty list
# user 2024308 has an empty list
# user 627042 has an empty list
# user 1924476 has an empty list
# user 831279 has an empty list
# user 878715 has an empty list
# user 4227887 has an empty list
# user 1744723 has an empty list
# user 2420649 has an empty list
# user 1926586 has an empty list
# user 1968271 has an empty list
# user 1334479 has an empty list
# user 1532501 has an empty list
# user 3131685 has an empty list
# user 242247 has an empty list
# user 4370685 has an empty list
# user 1709387 has an empty list
# user 4676222 has an empty list
# user 2689953 has an empty list
# user 1341282 has an empty list
# user 1879722 has an empty list
# user 2670059 has an empty list
# user 1796587 has an empty list
# user 4185677 has an empty list
# user 1003737 has an empty list
# user 934755 has an empty list
# user 4560837 has an empty list
# user 1967507 has an empty list
# user 3979485 has an empty list
# user 3817325 has an empty list
# user 21636 has an empty list
# user 3163712 has an empty list
# user 206835 has an empty list
# user 3271631 has an empty list
# user 826837 has an empty list
# user 4569952 has an empty list
# user 2473545 has an empty list
# user 321431 has an empty list
# user 794010 has an empty list
# user 856048 has an empty list
# user 1401234 has an empty list
# user 2986343 has an empty list
# user 361816 has an empty list
# user 542475 has an empty list
# user 2811628 has an empty list
# user 3996836 has an empty list
# user 163964 has an empty list
# user 2558441 has an empty list
# user 1069857 has an empty list
# user 1374102 has an empty list
# user 1267143 has an empty list
# user 589419 has an empty list
# user 3236982 has an empty list
# user 2297177 has an empty list
# user 3212423 has an empty list
# user 4686723 has an empty list
# user 2688024 has an empty list
# user 3761646 has an empty list
# user 3975782 has an empty list
# user 97323 has an empty list
# user 4766178 has an empty list
# user 4657414 has an empty list
# user 3947478 has an empty list
# user 2761447 has an empty list
# user 362394 has an empty list
# user 2683907 has an empty list
# user 414098 has an empty list
# user 2119928 has an empty list
# user 765988 has an empty list
# user 1560259 has an empty list
# user 1368649 has an empty list
# user 1399916 has an empty list
# user 400487 has an empty list
# user 2674538 has an empty list
# user 228532 has an empty list
# user 320204 has an empty list
# user 66266 has an empty list
# user 4209977 has an empty list
# user 2715765 has an empty list
# user 2535482 has an empty list
# user 4398829 has an empty list
# user 1621748 has an empty list
# user 2073090 has an empty list
# user 604781 has an empty list
# user 4316455 has an empty list
# user 2300767 has an empty list
# user 1244714 has an empty list
# user 3173146 has an empty list
# user 3114492 has an empty list
# user 3220408 has an empty list
# user 4789707 has an empty list
# user 2828151 has an empty list
# user 2723844 has an empty list
# user 610192 has an empty list
# user 2700971 has an empty list
# user 777189 has an empty list
# user 396874 has an empty list
# user 3466772 has an empty list
# user 3725739 has an empty list
# user 3777539 has an empty list
# user 3412708 has an empty list
# user 1542757 has an empty list
# user 2027398 has an empty list
# user 2623331 has an empty list
# user 1022068 has an empty list
# user 3191567 has an empty list
# user 1045145 has an empty list
# user 3983129 has an empty list
# user 3328177 has an empty list
# user 3093662 has an empty list
# user 4057553 has an empty list
# user 4687386 has an empty list
# user 4655508 has an empty list
# user 2755801 has an empty list
# user 2285473 has an empty list
# user 2523675 has an empty list
# user 2866028 has an empty list
# user 480918 has an empty list
# user 740980 has an empty list
# user 1685519 has an empty list
# user 1278513 has an empty list
# user 425335 has an empty list
# user 3755809 has an empty list
# user 3242247 has an empty list
# user 325355 has an empty list
# user 3878498 has an empty list
# user 2438940 has an empty list
# user 594204 has an empty list
# user 1935440 has an empty list
# user 2751500 has an empty list
# user 1175426 has an empty list
# user 2978314 has an empty list
# user 3938185 has an empty list
# user 3903087 has an empty list
# user 3707771 has an empty list
# user 1914380 has an empty list
# user 1728005 has an empty list
# user 4124420 has an empty list
# user 172437 has an empty list
# user 2202318 has an empty list
# user 2925336 has an empty list
# user 2205254 has an empty list
# user 2894566 has an empty list
# user 2512358 has an empty list
# user 2187688 has an empty list
# user 2670745 has an empty list
# user 1819085 has an empty list
# user 1390397 has an empty list
# user 2781759 has an empty list
# user 3098020 has an empty list
# user 1805960 has an empty list
# user 165583 has an empty list
# user 2713756 has an empty list
# user 1592384 has an empty list
# user 2259866 has an empty list
# user 83665 has an empty list
# user 3377195 has an empty list
# user 3060397 has an empty list
# user 3149197 has an empty list
# user 3813263 has an empty list
# user 1977116 has an empty list
# user 4323270 has an empty list
# user 162185 has an empty list
# user 3507650 has an empty list
# user 1696496 has an empty list
# user 246322 has an empty list
# user 1415607 has an empty list
# user 4430337 has an empty list
# user 4664599 has an empty list
# user 4648164 has an empty list
# user 1932552 has an empty list
# user 2794410 has an empty list
# user 527343 has an empty list
# user 4449790 has an empty list
# user 4517851 has an empty list
# user 775212 has an empty list
# user 1408846 has an empty list
# user 4807809 has an empty list
# user 3199997 has an empty list
# user 611157 has an empty list
# user 1973694 has an empty list
# user 1536736 has an empty list
# user 4218760 has an empty list
# user 926529 has an empty list
# user 2636089 has an empty list
# user 4723308 has an empty list
# user 1030546 has an empty list
# user 1800178 has an empty list
# user 3716416 has an empty list
# user 1142650 has an empty list
# user 323461 has an empty list
# user 2309452 has an empty list
# user 2276794 has an empty list
# user 2572009 has an empty list
# user 3408004 has an empty list
# user 2221712 has an empty list
# user 3048425 has an empty list
# user 1326751 has an empty list
# user 2822329 has an empty list
# user 4386843 has an empty list
# user 4239696 has an empty list
# user 3860055 has an empty list
# user 3886988 has an empty list
# user 3455874 has an empty list
# user 4121112 has an empty list
# user 3806186 has an empty list
# user 3840632 has an empty list
# user 1443138 has an empty list
# user 1549527 has an empty list
# user 2821879 has an empty list
# user 3246011 has an empty list
# user 2809343 has an empty list
# user 1050824 has an empty list
# user 2856610 has an empty list
# user 4133272 has an empty list
# user 991993 has an empty list
# user 3974481 has an empty list
# user 3856351 has an empty list
# user 4080534 has an empty list
# user 1643681 has an empty list
# user 2635425 has an empty list
# user 4368921 has an empty list
# user 2964178 has an empty list
# user 284765 has an empty list
# user 2387823 has an empty list
# user 1144038 has an empty list
# user 2469348 has an empty list
# user 4682420 has an empty list
# user 752007 has an empty list
# user 3976327 has an empty list
# user 2062461 has an empty list
# user 928855 has an empty list
# user 3787695 has an empty list
# user 3149410 has an empty list
# user 3916708 has an empty list
# user 4485368 has an empty list
# user 4846182 has an empty list
# user 173692 has an empty list
# user 2483258 has an empty list
# user 4600031 has an empty list
# user 1407969 has an empty list
# user 1177802 has an empty list
# user 3737947 has an empty list
# user 4856592 has an empty list
# user 4793930 has an empty list
# user 3832643 has an empty list
# user 2850237 has an empty list
# user 1650749 has an empty list
# user 165650 has an empty list
# user 3064201 has an empty list
# user 578545 has an empty list
# user 2094764 has an empty list
# user 4409924 has an empty list
# user 1314591 has an empty list
# user 461221 has an empty list
# user 3584860 has an empty list
# user 1092059 has an empty list
# user 4102645 has an empty list
# user 3873192 has an empty list
# user 2153990 has an empty list
# user 4496060 has an empty list
# user 3724229 has an empty list
# user 764816 has an empty list
# user 118439 has an empty list
# user 4702673 has an empty list
# user 4166900 has an empty list
# user 125849 has an empty list
# user 587873 has an empty list
# user 2904942 has an empty list
# user 2887707 has an empty list
# user 2950754 has an empty list
# user 242617 has an empty list
# train.txt is inputed

# %%
test_set = {}
test_result=[]
with open('test-public.txt', "r") as f:
    # read header and pass
    line = f.readline()
    # read data
    line = f.readline().strip()
    while line:
        piece = line.split("\t")
        test_set[piece[1]] = piece[2]
        test_result.append((piece[1],piece[2]))
        line = f.readline().strip()
print("test-public.txt is inputed.")
# Out:
# test-public.txt is inputed.

# %%
metrics = ['CN', 'JC', 'SI', 'SC', 'HP', 'HD', 'LHN', 'RA', 'PA']
"""
mode list:
feature explanation: reference from https://arxiv.org/pdf/1411.5118.pdf
follow means source user follow others
follow by means source user followed by others
intersection: source user follow and target user follow by
reverse_intersection:  source user follow by and target user follow
"""
# modes = ['follow', 'follow_by', 'intersection', 'reverse_intersection']
modes = ['follow_by', 'intersection']

# %%
features = ['source', 'target', 'exist',
            'user_follow_num_source', 'follow_user_num_source',
            'follow_user_num_target','v_community']
for mode in modes:
    for metric in metrics:
        features.append(mode + '_' + metric)
print("feature is created with dictionary: /n {}".format(features))
# Out:
# feature is created with dictionary: /n ['source', 'target', 'exist', 'user_follow_num_source', 'follow_user_num_source', 'follow_user_num_target', 'v_community', 'follow_by_CN', 'follow_by_JC', 'follow_by_SI', 'follow_by_SC', 'follow_by_HP', 'follow_by_HD', 'follow_by_LHN', 'follow_by_RA', 'follow_by_PA', 'intersection_CN', 'intersection_JC', 'intersection_SI', 'intersection_SC', 'intersection_HP', 'intersection_HD', 'intersection_LHN', 'intersection_RA', 'intersection_PA']

# %%
def calculate_metric(mode, source=None, target=None):
    # if mode is 'follow':
    #     first_list = user_follow.get(source, set()) # safe
    #     second_list = user_follow.get(target, set())
    # elif mode is 'follow_by':
    #     first_list = follow_user.get(source, set()) # safe
    #     second_list = follow_user.get(target, set()) # safe
    # elif mode is 'intersection':
    #     first_list = user_follow.get(source, set()) # safe
    #     second_list = follow_user.get(target, set()) # safe
    # else:
    #     first_list = follow_user.get(source, set()) # safe
    #     second_list = user_follow.get(target, set())

    if mode is 'follow_by':
        first_list = follow_user.get(source, set())  # safe
        second_list = follow_user.get(target, set())  # safe
    elif mode is 'intersection':
        first_list = user_follow.get(source, set())  # safe
        second_list = follow_user.get(target, set())  # safe
    else:
        print('Error, unknown mode {}'.format(mode))
        sys.exit(0)
    intersection = first_list & second_list
    union = first_list | second_list
    PA = len(first_list) * len(second_list)
    CN = float(len(intersection))
    JC = CN / len(union)
    SI = CN / (len(first_list) + len(second_list))
    SC = CN / math.sqrt(len(first_list) * len(second_list))
    HP = CN / min(len(first_list), len(second_list))
    HD = CN / max(len(first_list), len(second_list))
    LHN = CN / PA
    CN = int(CN)
    RA = 0
    # calculate RA
    if mode is "follow_by":
        for i in intersection:
            if user_follow_num.get(i):
                RA += float(1) / user_follow_num.get(i)
    elif mode is "intersection":
        # note that source follow more user, less important this intermediary is
        #           more user follow i, less important this intermediary is
        #           i follow more user , less important this intermediary is
        #           more user follow target, less important this intermediary is
        for i in intersection:
            res = user_follow_num.get(source, 0) * \
                  follow_user_num.get(i, 0) * \
                  user_follow_num.get(i, 0) * \
                  follow_user_num.get(target, 0)
            if res != 0:
                RA += float(1) / res
    else:
        for i in intersection:
            # note that target follow more user, less important this intermediary is
            #           more user follow i, less important this intermediary is
            #           i follow more user , less important this intermediary is
            #           more user follow source, less important this intermediary is
            res = user_follow_num.get(target, 0) * \
                  follow_user_num.get(i, 0) * \
                  user_follow_num.get(i, 0) * \
#  (555, '4091626'),
#  (555, '402665'),
#  (555, '3151068'),
#  (555, '2835234'),
#  (555, '2464279'),
#  (554, '856916'),
#  (554, '4520262'),
#  (554, '3279714'),
#  (554, '2957222'),
#  (554, '2903457'),
#  (554, '1401429'),
#  (553, '65081'),
#  (553, '2215646'),
#  (553, '1246697'),
#  (552, '978586'),
#  (552, '4846084'),
#  (552, '4097481'),
#  (552, '2500149'),
#  (551, '663713'),
#  (551, '589398'),
#  (551, '4121411'),
#  (551, '3162560'),
#  (551, '2768159'),
#  (551, '2764439'),
#  (551, '2620980'),
#  (551, '2107218'),
#  (551, '1525155'),
#  (551, '1494526'),
#  (550, '839613'),
#  (550, '4822560'),
#  (550, '4720208'),
#  (550, '3695049'),
#  (549, '3156984'),
#  (549, '2807412'),
#  (549, '1695300'),
#  (549, '1253026'),
#  (548, '745687'),
#  (548, '454180'),
#  (548, '285814'),
#  (548, '1322106'),
#  (547, '2248700'),
#  (547, '1943329'),
#  (546, '3738824'),
#  (546, '227738'),
#  (546, '1560763'),
#  (546, '1434421'),
#  (546, '1085187'),
#  (545, '569758'),
#  (545, '550773'),
#  (545, '4684772'),
#  (545, '4593403'),
#  (545, '2865530'),
#  (545, '2471048'),
#  (545, '1244776'),
#  (544, '984872'),
#  (544, '3068613'),
#  (543, '2283044'),
#  (543, '2017471'),
#  (542, '3543842'),
#  (542, '3428320'),
#  (541, '3613442'),
#  (541, '356686'),
#  (541, '24723'),
#  (540, '3793063'),
#  (540, '3734691'),
#  (540, '2443492'),
#  (539, '229905'),
#  (539, '1796644'),
#  (538, '4166170'),
#  (538, '3086178'),
#  (538, '1413177'),
#  (538, '1058170'),
#  (537, '3089513'),
#  (537, '2273355'),
#  (537, '1862725'),
#  (537, '1839728'),
#  (536, '2840014'),
#  (535, '3305728'),
#  (535, '2998332'),
#  (534, '1140217'),
#  (534, '1078607'),
#  (533, '99644'),
#  (533, '4799107'),
#  (533, '3809903'),
#  (533, '3584952'),
#  (533, '3068375'),
#  (533, '2268771'),
#  (533, '2019650'),
#  (532, '4506248'),
#  (532, '3688370'),
#  (532, '2763386'),
#  (531, '369068'),
#  (531, '340818'),
#  (531, '1468454'),
#  (530, '94866'),
#  (530, '4076988'),
#  (530, '3275722'),
#  (530, '3004637'),
#  (530, '2533111'),
#  (529, '2161208'),
#  (529, '1263573'),
#  (528, '263909'),
#  (528, '2102888'),
#  (527, '3353876'),
#  (527, '225753'),
#  (526, '4851420'),
#  (526, '4821620'),
#  (526, '4820881'),
#  (526, '4808386'),
#  (526, '4108497'),
#  (526, '2757201'),
#  (526, '2498462'),
#  (526, '157899'),
#  (525, '287025'),
#  (523, '4035076'),
#  (523, '3785405'),
#  (523, '3579320'),
#  (523, '3487630'),
#  (523, '1447025'),
#  (523, '126673'),
#  (522, '3442801'),
#  (522, '2991814'),
#  (521, '629046'),
#  ...]

# %%
def generate_train_set():
    user_list = list(user_follow.keys())
    follow_list = list(follow_user.keys())
    with open("train_set.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=features)
        writer.writeheader()
        for i in tqdm(range(50000)):
            try:
                source = random.choice(user_list)
                target = random.choice(list(user_follow.get(source)))
                community = 0
                if '20388' in user_follow[source] and '20388' in follow_user[target]:
                    community = 1
                else:
                    community = 0
                feature_for_this = {'source': source,
                                    'target': target,
                                    'exist': 1,
                                    'user_follow_num_source': user_follow_num.get(source),
                                    'follow_user_num_source': follow_user_num.get(source),
                                    'follow_user_num_target': follow_user_num.get(target),
                                    'v_community':community}
                for mode in modes:
                    for one_metrics in list(zip(calculate_metric(mode=mode, source=source, target=target), metrics)):
                        feature_for_this[mode + '_' + one_metrics[1]] = one_metrics[0]
                writer.writerow(feature_for_this)
            except IndexError:
                pass
        print('positive sample generated')
        gc.collect()
        for i in tqdm(range(50000)):
            try:
                source = random.choice(user_list)
                while (True):
                    target = random.choice(follow_list)
                    if target in (user_follow.get(source)) or test_set.get(source) == target:
                        continue
                    else:
                        break
                community = 0
                if '20388' in user_follow[source] and '20388' in follow_user[target]:
                    community = 1
                else:
                    community = 0
                feature_for_this = {'source': source,
                                    'target': target,
                                    'exist': 0,
                                    'user_follow_num_source': user_follow_num.get(source),
                                    'follow_user_num_source': follow_user_num.get(source),
                                    'follow_user_num_target': follow_user_num.get(target),
                                    'v_community': community}
                for mode in modes:
                    for one_metrics in list(zip(calculate_metric(mode=mode, source=source, target=target), metrics)):
                        feature_for_this[mode + '_' + one_metrics[1]] = one_metrics[0]
                writer.writerow(feature_for_this)
            except IndexError:
                pass
        print('negative samples generated')
        gc.collect()
generate_train_set()
# Out:
# 100%|██████████| 50000/50000 [00:20<00:00, 2463.50it/s]
#   0%|          | 69/50000 [00:00<01:13, 677.38it/s]
# positive sample generated
# 100%|██████████| 50000/50000 [00:13<00:00, 3633.46it/s]
# negative samples generated

# %%
def generate_test_set():
    with open("test_set.csv", "w", newline="") as f:
        features.remove('exist')
        writer = csv.DictWriter(f, fieldnames=features)
        writer.writeheader()
        for test_sample in tqdm(test_result):
            community = 0
            if '20388' in user_follow[source] and '20388' in follow_user[target]:
                community = 1
            else:
                community = 0
            feature_for_this = {'source': test_sample[0],
                                'target': test_sample[1],
                                'user_follow_num_source': user_follow_num.get(test_sample[0]),
                                'follow_user_num_source': follow_user_num.get(test_sample[0]),
                                'follow_user_num_target': follow_user_num.get(test_sample[1]),
                                'v_community':community}
            for mode in modes:
                for one_metrics in list(zip(calculate_metric(mode=mode, source=test_sample[0], target=test_sample[1]), metrics)):
                    feature_for_this[mode + '_' + one_metrics[1]] = one_metrics[0]
            writer.writerow(feature_for_this)
        print('testcsv is generated')
generate_test_set()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-66fe31be089e> in <module>()
#      21             writer.writerow(feature_for_this)
#      22         print('testcsv is generated')
# ---> 23 generate_test_set()
#
# <ipython-input-9-66fe31be089e> in generate_test_set()
#       6         for test_sample in tqdm(test_result):
#       7             community = 0
# ----> 8             if '20388' in user_follow[source] and '20388' in follow_user[target]:
#       9                 community = 1
#      10             else:
#
# NameError: name 'source' is not defined
